# %%
import pandas as pd

# Load complete ticket details from CSV
file_path = '../data/complete_ticket_details.csv'
complete_ticket_details = pd.read_csv(file_path)

# Display the first few rows of the dataframe
print(complete_ticket_details.head())
# Out:
#                cc_emails fwd_emails        reply_cc_emails ticket_cc_emails  \
# 0                     []         []                     []               []
# 1                     []         []                     []              NaN
# 2  ['isralog@gmail.com']         []  ['isralog@gmail.com']              NaN
# 3                     []         []                     []              NaN
# 4                     []         []                     []              NaN
#
#   ticket_bcc_emails  fr_escalated   spam  email_config_id  group_id  priority  \
# 0                []          True  False              NaN       NaN         1
# 1                []         False  False     5.000016e+09       NaN         1
# 2                []          True  False              NaN       NaN         1
# 3                []         False  False     5.000016e+09       NaN         1
# 4                []         False  False              NaN       NaN         1
#
#    ...             fr_due_by  is_escalated  \
# 0  ...  2014-03-18T16:00:00Z          True
# 1  ...  2014-09-08T15:00:00Z         False
# 2  ...  2014-10-03T12:17:55Z          True
# 3  ...  2014-10-17T08:15:31Z         False
# 4  ...  2014-10-14T11:43:55Z         False
#
#                                          description  \
# 0  <div>yeah we don't really login to that accoun...
# 1          <div dir="ltr">How does this look</div>\n
# 2  <div>Hi, </div>\n<div>i am using soap for node...
# 3  <div>I’m trying to find a static IP service to...
# 4  <div>Hi,</div>\n<div>how can i do that thing&g...
#
#                                     description_text  \
# 0  yeah we don't really login to that account. co...
# 1                               How does this look\n
# 2  Hi,   i am using soap for node, and would like...
# 3  I'm trying to find a static IP service to use ...
# 4          Hi,  how can i do that thing>     Thanks.
#
#                 custom_fields            created_at            updated_at  \
# 0  {'cf_subscriptions': None}  2014-03-17T18:58:42Z  2014-09-08T07:19:36Z
# 1  {'cf_subscriptions': None}  2014-09-07T20:51:08Z  2014-09-08T07:19:50Z
# 2  {'cf_subscriptions': None}  2014-10-02T12:17:55Z  2014-10-09T19:11:00Z
# 3  {'cf_subscriptions': None}  2014-10-12T16:39:56Z  2014-10-16T08:26:39Z
# 4  {'cf_subscriptions': None}  2014-10-13T11:43:55Z  2014-10-13T11:44:25Z
#
#   tags attachments  source_additional_info
# 0   []          []                     NaN
# 1   []          []                     NaN
# 2   []          []                     NaN
# 3   []          []                     NaN
# 4   []          []                     NaN
#
# [5 rows x 33 columns]

# %%
most_recent_ticket = complete_ticket_details.loc[complete_ticket_details['created_at'].idxmax()]
print("Most Recent Ticket:")
print(most_recent_ticket)
# Out:
# Most Recent Ticket:
# cc_emails                                                                []
# fwd_emails                                                               []
# reply_cc_emails                                                          []
# ticket_cc_emails                                                         []
# ticket_bcc_emails                                                        []
# fr_escalated                                                          False
# spam                                                                  False
# email_config_id                                                5000016478.0
# group_id                                                                NaN
# priority                                                                  1
# requester_id                                                    12060524000
# responder_id                                                   5021537993.0
# source                                                                   10
# company_id                                                              NaN
# status                                                                    5
# subject                          [QuotaGuard] Account Verification Required
# association_type                                                        NaN
# support_email                                        support@quotaguard.com
# to_emails                                        ['support@quotaguard.com']
# product_id                                                              NaN
# id                                                                     8236
# type                                                                    NaN
# due_by                                                 2025-02-25T15:58:25Z
# fr_due_by                                              2025-02-23T15:58:25Z
# is_escalated                                                          False
# description               <div>Thank you for signing up with QuotaGuard’...
# description_text          Thank you for signing up with QuotaGuard’s Sta...
# custom_fields                                    {'cf_subscriptions': None}
# created_at                                             2025-02-22T07:32:05Z
# updated_at                                             2025-02-22T15:58:25Z
# tags                                                                     []
# attachments                                                              []
# source_additional_info                                                  NaN
# Name: 2959, dtype: object
